# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/ASUS/Desktop/Games/games_data.csv',encoding='latin1')

# %%
df
# Out:
#       game_id                              name  \
# 0        3498                Grand Theft Auto V
# 1        3328          The Witcher 3: Wild Hunt
# 2        4200                          Portal 2
# 3        4291  Counter-Strike: Global Offensive
# 4        5286                Tomb Raider (2013)
# ...       ...                               ...
# 10404    5002                        Cricket 07
# 10405    5003                        Cricket 24
# 10406    5004            Don Bradman Cricket 17
# 10407    5005                Ashes Cricket 2009
# 10408    5006      World Cricket Championship 2
#
#                                              description  \
# 0      <p>Rockstar Games went bigger, since their pre...
# 1      <p>The third game in a series, it holds nothin...
# 2      <p>Portal 2 is a first-person puzzle game deve...
# 3      <p>Counter-Strike is a multiplayer phenomenon ...
# 4      <p>A cinematic revival of the series in its ac...
# ...                                                  ...
# 10404  Cricket 07 is a 2006 cricket simulation comput...
# 10405  Cricket 24 is a cricket video game developed b...
# 10406  Don Bradman Cricket 17 is a cricket video game...
# 10407  Ashes Cricket 2009 is a cricket video game dev...
# 10408  World Cricket Championship 2' has features tha...
#
#                                                   genres  \
# 0                                                 Action
# 1                                            Action, RPG
# 2                                        Shooter, Puzzle
# 3                                                Shooter
# 4                                                 Action
# ...                                                  ...
# 10404                                             Sports
# 10405  Sports Video Game, Simulation Video Game, Simu...
# 10406                      Simulation Video Game, Sports
# 10407                 Sports Video Game, Simulation Game
# 10408                                             Sports
#
#                                                platforms rating    released  \
# 0      PC, PlayStation 5, Xbox Series S/X, PlayStatio...   4.47  17-09-2013
# 1      Xbox Series S/X, PlayStation 5, macOS, PlaySta...   4.65  18-05-2015
# 2      PlayStation 3, PC, Xbox 360, Linux, macOS, Xbo...   4.59  18-04-2011
# 3                     PC, Linux, Xbox 360, PlayStation 3   3.56  21-08-2012
# 4      PlayStation 3, Xbox 360, macOS, PC, Xbox One, ...   4.06  05-03-2013
# ...                                                  ...    ...         ...
# 10404                             PC,PlayStation,Windows    4.7  16-11-2006
# 10405       PlaysStation,Xbox,Windows,PC,Nintendo Switch    3.5  05-10-2023
# 10406         PlayStation 4, Xbox One, Microsoft Windows   3.45  15-12-2016
# 10407                       Windows,Xbox 360,PlayStation    3.1  06-08-2009
# 10408                                Andriod,Ios,Windows    4.3  14-09-2015
#
#                                              cover_image  \
# 0      https://media.rawg.io/media/games/20a/20aa03a1...
# 1      https://media.rawg.io/media/games/618/618c2031...
# 2      https://media.rawg.io/media/games/2ba/2bac0e87...
# 3      https://media.rawg.io/media/games/736/73619bd3...
# 4      https://media.rawg.io/media/games/021/021c4e21...
# ...                                                  ...
# 10404  https://images.launchbox-app.com/d6fccb94-c73b...
# 10405  https://shared.cloudflare.steamstatic.com/stor...
# 10406  https://i.ytimg.com/vi/onuADtmG5H0/maxresdefau...
# 10407  https://m.media-amazon.com/images/I/81rZ6uv0gB...
# 10408  https://wcc1-website-assets.s3.ap-southeast-1....
#
#                                                game_link  \
# 0               https://rawg.io/games/grand-theft-auto-v
# 1          https://rawg.io/games/the-witcher-3-wild-hunt
# 2                         https://rawg.io/games/portal-2
# 3      https://rawg.io/games/counter-strike-global-of...
# 4                      https://rawg.io/games/tomb-raider
# ...                                                  ...
# 10404       https://oldgamesdownload.com/cricket-07-bdt/
# 10405                                                NaN
# 10406  https://store.steampowered.com/app/464850/Don_...
# 10407  https://www.cricketweb.net/game/ashes-cricket-...
# 10408  https://apps.microsoft.com/detail/9nblggh5xc9k...
#
#                                           metacritic_url
# 0      <p>Rockstar Games went bigger, since their pre...
# 1      <p>The third game in a series, it holds nothin...
# 2      <p>Portal 2 is a first-person puzzle game deve...
# 3      <p>Counter-Strike is a multiplayer phenomenon ...
# 4      <p>A cinematic revival of the series in its ac...
# ...                                                  ...
# 10404                                                NaN
# 10405                                                NaN
# 10406                                                NaN
# 10407                                                NaN
# 10408                                                NaN
#
# [10409 rows x 10 columns]

# %%
df = df.drop(['metacritic_url'],axis=1)

# %%
df.loc[df['game_id'] == '5003', 'game_link'] = "https://store.steampowered.com/app/2358260/Cricket_24/"
df.loc[df['game_id'] == '5004', 'cover_image'] = "https://m.media-amazon.com/images/I/81vula5GKpL.jpg"

# %%
df.fillna('',inplace=True)

# %%
df
# Out:
#       game_id                              name  \
# 0        3498                Grand Theft Auto V
# 1        3328          The Witcher 3: Wild Hunt
# 2        4200                          Portal 2
# 3        4291  Counter-Strike: Global Offensive
# 4        5286                Tomb Raider (2013)
# ...       ...                               ...
# 10404    5002                        Cricket 07
# 10405    5003                        Cricket 24
# 10406    5004            Don Bradman Cricket 17
# 10407    5005                Ashes Cricket 2009
# 10408    5006      World Cricket Championship 2
#
#                                              description  \
# 0      <p>Rockstar Games went bigger, since their pre...
# 1      <p>The third game in a series, it holds nothin...
# 2      <p>Portal 2 is a first-person puzzle game deve...
# 3      <p>Counter-Strike is a multiplayer phenomenon ...
# 4      <p>A cinematic revival of the series in its ac...
# ...                                                  ...
# 10404  Cricket 07 is a 2006 cricket simulation comput...
# 10405  Cricket 24 is a cricket video game developed b...
# 10406  Don Bradman Cricket 17 is a cricket video game...
# 10407  Ashes Cricket 2009 is a cricket video game dev...
# 10408  World Cricket Championship 2' has features tha...
#
#                                                   genres  \
# 0                                                 Action
# 1                                            Action, RPG
# 2                                        Shooter, Puzzle
# 3                                                Shooter
# 4                                                 Action
# ...                                                  ...
# 10404                                             Sports
# 10405  Sports Video Game, Simulation Video Game, Simu...
# 10406                      Simulation Video Game, Sports
# 10407                 Sports Video Game, Simulation Game
# 10408                                             Sports
#
#                                                platforms rating    released  \
# 0      PC, PlayStation 5, Xbox Series S/X, PlayStatio...   4.47  17-09-2013
# 1      Xbox Series S/X, PlayStation 5, macOS, PlaySta...   4.65  18-05-2015
# 2      PlayStation 3, PC, Xbox 360, Linux, macOS, Xbo...   4.59  18-04-2011
# 3                     PC, Linux, Xbox 360, PlayStation 3   3.56  21-08-2012
# 4      PlayStation 3, Xbox 360, macOS, PC, Xbox One, ...   4.06  05-03-2013
# ...                                                  ...    ...         ...
# 10404                             PC,PlayStation,Windows    4.7  16-11-2006
# 10405       PlaysStation,Xbox,Windows,PC,Nintendo Switch    3.5  05-10-2023
# 10406         PlayStation 4, Xbox One, Microsoft Windows   3.45  15-12-2016
# 10407                       Windows,Xbox 360,PlayStation    3.1  06-08-2009
# 10408                                Andriod,Ios,Windows    4.3  14-09-2015
#
#                                              cover_image  \
# 0      https://media.rawg.io/media/games/20a/20aa03a1...
# 1      https://media.rawg.io/media/games/618/618c2031...
# 2      https://media.rawg.io/media/games/2ba/2bac0e87...
# 3      https://media.rawg.io/media/games/736/73619bd3...
# 4      https://media.rawg.io/media/games/021/021c4e21...
# ...                                                  ...
# 10404  https://images.launchbox-app.com/d6fccb94-c73b...
# 10405  https://shared.cloudflare.steamstatic.com/stor...
# 10406  https://m.media-amazon.com/images/I/81vula5GKp...
# 10407  https://m.media-amazon.com/images/I/81rZ6uv0gB...
# 10408  https://wcc1-website-assets.s3.ap-southeast-1....
#
#                                                game_link
# 0               https://rawg.io/games/grand-theft-auto-v
# 1          https://rawg.io/games/the-witcher-3-wild-hunt
# 2                         https://rawg.io/games/portal-2
# 3      https://rawg.io/games/counter-strike-global-of...
# 4                      https://rawg.io/games/tomb-raider
# ...                                                  ...
# 10404       https://oldgamesdownload.com/cricket-07-bdt/
# 10405  https://store.steampowered.com/app/2358260/Cri...
# 10406  https://store.steampowered.com/app/464850/Don_...
# 10407  https://www.cricketweb.net/game/ashes-cricket-...
# 10408  https://apps.microsoft.com/detail/9nblggh5xc9k...
#
# [10409 rows x 9 columns]

# %%
import pandas as pd
from fuzzywuzzy import fuzz
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity



# Preprocess
df["combined"] = df["genres"] + " " + df["platforms"]

# Vectorize features using the combined column of the DataFrame
vectorizer = TfidfVectorizer(stop_words="english")
feature_matrix = vectorizer.fit_transform(df["combined"]) # Calculate the feature matrix based on the entire DataFrame
similarity_matrix = cosine_similarity(feature_matrix) # Calculate the similarity matrix based on the entire DataFrame


# Fuzzy matching function
def find_closest_game(query, titles):
    scores = [(title, fuzz.token_sort_ratio(query.lower(), title.lower())) for title in titles]
    return max(scores, key=lambda x: x[1])[0]

# Recommendation function
def recommend_games(query, titles, similarity_matrix, data, top_n=5):
    closest_title = find_closest_game(query, titles)
    game_idx = data[data["name"] == closest_title].index[0]  # Updated column name
    sim_scores = list(enumerate(similarity_matrix[game_idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    top_indices = [idx for idx, score in sim_scores[1:top_n+1]]
    return data.iloc[top_indices][["name", "genres", "platforms", "rating"]]  # Updated column name

# Example usage
query = "elder ring"
recommendations = recommend_games(query, df["name"], similarity_matrix, df)  # Updated column name

# %%
recommendations
# Out:
#                                          name       genres  \
# 1159   Vampire: The Masquerade - Bloodlines 2  Action, RPG
# 1707                           Tales of Arise  Action, RPG
# 2093                                Diablo IV  Action, RPG
# 9292                                  Godfall  Action, RPG
# 10314                                 ELEX II  Action, RPG
#
#                                                platforms rating
# 1159   PC, PlayStation 5, Xbox Series S/X, Xbox One, ...   3.88
# 1707   PlayStation 4, Xbox Series S/X, Xbox One, Play...   3.95
# 2093   PC, Xbox Series S/X, PlayStation 5, Xbox One, ...   3.79
# 9292   PC, PlayStation 4, PlayStation 5, Xbox One, Xb...   2.49
# 10314  PlayStation 4, Xbox One, Xbox Series S/X, Play...   3.34

# %%
import pandas as pd
from fuzzywuzzy import fuzz
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from datetime import datetime

# Assuming df is already loaded; replace with your data loading if needed
# Example: df = pd.read_csv('your_file.csv')

# Validate required columns
required_columns = ["name", "genres", "platforms", "rating", "released", "cover_image", "game_link"]
missing_cols = [col for col in required_columns if col not in df.columns]
if missing_cols:
    raise KeyError(f"Missing columns: {missing_cols}. Available columns: {list(df.columns)}")

# Preprocess released to extract year
def extract_year(date_str):
    try:
        return datetime.strptime(date_str, "%d-%m-%Y").year  # Adjust format if needed
    except:
        return None

df["release_year"] = df["released"].apply(extract_year)

# Preprocess: Combine features for content-based filtering
df["combined"] = df["genres"] + " " + df["platforms"]

# Vectorize features
vectorizer = TfidfVectorizer(stop_words="english")
feature_matrix = vectorizer.fit_transform(df["combined"])
similarity_matrix = cosine_similarity(feature_matrix)

# Fuzzy matching function
def find_closest_game(query, titles):
    scores = [(title, fuzz.token_sort_ratio(query.lower(), title.lower())) for title in titles]
    best_match, score = max(scores, key=lambda x: x[1])
    if score < 50:  # Threshold for low confidence matches
        raise ValueError(f"No close match found for '{query}'")
    return best_match

# Recommendation function with release date priority
def recommend_games(query, titles, similarity_matrix, data, top_n=5, date_weight=0.4):
    # Find closest game
    closest_title = find_closest_game(query, titles)
    game_idx = data[data["name"] == closest_title].index[0]

    # Get matched game's release year
    matched_year = data.loc[game_idx, "release_year"]
    if matched_year is None:
        raise ValueError(f"Release year missing for '{closest_title}'")

    # Calculate combined scores: similarity + release date boost
    sim_scores = []
    for idx, sim in enumerate(similarity_matrix[game_idx]):
        if idx == game_idx:
            continue  # Skip the matched game itself
        release_year = data.loc[idx, "release_year"]
        # Boost games released after or in the same year
        year_score = 1.0 if release_year is not None and release_year >= matched_year else 0.0
        combined_score = (1 - date_weight) * sim + date_weight * year_score
        sim_scores.append((idx, combined_score))

    # Sort by combined score
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    top_indices = [idx for idx, score in sim_scores[:top_n]]

    # Return selected columns
    return data.iloc[top_indices][["name", "genres", "platforms", "rating",
                                   "released", "cover_image", "game_link"]]

# Example usage
try:
    query = "World Cricket Championship 2"
    recommendations = recommend_games(
        query=query,
        titles=df["name"],
        similarity_matrix=similarity_matrix,
        data=df,
        top_n=5,
        date_weight=0.4  # 40% weight to release date, 60% to content similarity
    )
    print(f"Recommendations for '{query}':")
    print(recommendations.to_string(index=False))
except (KeyError, ValueError) as e:
    print(f"Error: {e}")
# Out:
# Recommendations for 'World Cricket Championship 2':
#                   name                        genres                                  platforms rating   released                                                                cover_image                                                         game_link
# Don Bradman Cricket 17 Simulation Video Game, Sports PlayStation 4, Xbox One, Microsoft Windows   3.45 15-12-2016                        https://m.media-amazon.com/images/I/81vula5GKpL.jpg https://store.steampowered.com/app/464850/Don_Bradman_Cricket_17/
#     eFootball PES 2020                        Sports            iOS, Android, PC, PlayStation 4   3.22 10-09-2019 https://media.rawg.io/media/games/2ed/2ed38a102fe66a0ea98a8e09c660a458.jpg                          https://rawg.io/games/efootball-pes-2020
#        MLB The Show 19                        Sports                              PlayStation 4   2.97 26-03-2019 https://media.rawg.io/media/games/e66/e6683904582e35ad06b7431c86475300.jpg                             https://rawg.io/games/mlb-the-show-19
#           Forza Street                Sports, Racing                           Android, PC, iOS   2.39 05-05-2018 https://media.rawg.io/media/games/f93/f93c0096c9a2ec6d3fdf91a15183e867.jpg                                https://rawg.io/games/forza-street
#        EA SPORTS UFC 3                        Sports                    Xbox One, PlayStation 4   3.58 02-02-2018 https://media.rawg.io/media/games/dbf/dbf2203a8529f6badb5546084db59f93.jpg                             https://rawg.io/games/ea-sports-ufc-3
